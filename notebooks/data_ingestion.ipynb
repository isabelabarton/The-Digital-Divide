# %% [markdown]
# ## Fetching Internet Users

# %%
import requests
import dotenv
import pandas as pd
import os
import json

# %%
r = requests.get('https://httpbin.org/user-agent')
useragent = r.json()['user-agent']
# Out:
# python-requests/2.32.5

# %%
useragent = 'Python-requests/2.32.5 (isabelabarton@gmail.com)'

headers = {'User-Agent': useragent,
           'From': 'isabelabarton@gmail.com'}

url = 'https://api.worldbank.org/v2/country/all/indicator/IT.NET.USER.ZS?format=json&per_page=20000'

#params = {'format': 'json', 
          #'per_page': 500}

response = requests.get(url, headers = headers)
data = response.json()

# %%
df = pd.DataFrame(data[1])
df.head()
# Out:
#                                            indicator  \
# 0  {'id': 'IT.NET.USER.ZS', 'value': 'Individuals...
# 1  {'id': 'IT.NET.USER.ZS', 'value': 'Individuals...
# 2  {'id': 'IT.NET.USER.ZS', 'value': 'Individuals...
# 3  {'id': 'IT.NET.USER.ZS', 'value': 'Individuals...
# 4  {'id': 'IT.NET.USER.ZS', 'value': 'Individuals...
#
#                                              country countryiso3code  date  \
# 0  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2024
# 1  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2023
# 2  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2022
# 3  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2021
# 4  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2020
#
#    value unit obs_status  decimal
# 0   35.0                        0
# 1   32.4                        0
# 2   30.2                        0
# 3   28.2                        0
# ...
